# %%
x = 1
y = 1
z = x + y
print("z = ", z)
# Out:
# z =  2

# %%
print("Hello, World!")
# Out:
# Hello, World!

# %%
seconds = 10**9
minutes = seconds // 60
hours = minutes // 60
days = hours // 24
years = days // 365
print("Years = ", years)
if years > 100:
    print("Baby will be dead by then")
else:
    print("Baby expected to live for one billion seconds")
# Out:
# Years =  31
# Baby expected to live for one billion seconds

# %% [markdown]
# Ex 1.6

# %%
def CompoundInterest(A, p, n):
    return A * (1 + p / 100)**n

# %%
print("Interest Rate after 5 years = ", CompoundInterest(1000, 5, 3))
# Out:
# Interest Rate after 5 years =  1157.6250000000002

# %% [markdown]
# Ex 1.7

# %%
x = 1; print 'sin(%g)=%g' % (x, sin(x))
# Out:
#   Cell In[11], line 1
#     x = 1; print 'sin(%g)=%g' % (x, sin(x))
#            ^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(...)?

# %%
#fixed code
from math import sin; x = 1; print('sin(%g)=%g' % (x, sin(x)))
# Out:
# sin(1)=0.841471

# %%
import math
# Tính logarithm tự nhiên
x = 10
result = math.log(x)  # log cơ số e của x

# %%
from math import tan
a = 4**3**2**3
print(a)

print("a2 = ", 4**18)
# Out:
# ...
# a2 =  68719476736
